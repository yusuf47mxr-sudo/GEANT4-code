# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,6))

plt.hist(branch_data,bins= 100)
plt.show()

# %%
import uproot
file = uproot.open("../build/Veri_t4.root")
tree = file["Olaylar"]
# Verileri doğrudan bir dizi olarak alabilirsiniz.
branch_data = tree["Enerji_MeV"].array(library="np") # NumPy dizisi olarak
print(branch_data)
# veya
import pandas as pd
df = tree.arrays(library="pd") # Pandas DataFrame olarak
print(df)
# Out:
# [1.3325     1.3325     0.49939492 1.3325     1.3325     1.1732
#  0.57982948 1.3325     1.1732     1.3325     1.1732     1.1732
#  1.3325     1.1732     0.31496603 0.20007295 0.53351204 0.08117547
#  0.88291895 1.3325     1.1732     1.3325     0.96826596 1.1732
#  1.1732     1.1732     1.3325     0.6739588  1.1732     1.3325
#  1.1732     1.1732     1.1732     1.1732     1.3325     1.1732
#  1.3325     1.1732     1.1732     0.45103301 0.28128773 0.10164764
#  0.50179264 1.3325     1.1732     1.3325     1.3325     1.3325
#  1.3325     1.3325     1.1732     0.71447111 1.3325     1.3325
#  0.06220804 1.3325     1.1732     1.1732     1.1732     1.3325
#  0.82871318 1.1732     1.1732     1.3325     1.3325     0.6401211
#  0.07464419 1.1732     0.91988234 0.8047659  1.3325     0.08484995
#  1.3325     1.1732     1.3325     1.1732     0.22645605 0.58993904
#  0.45090786 1.3325     0.9092166  1.1732     0.38907338 0.77853696
#  0.66011819 0.40195668 1.1732     0.39370633 1.1732     1.1732
# ...
