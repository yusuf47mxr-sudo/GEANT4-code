# %%
import numpy as np
import uproot
import matplotlib.pyplot as plt

# %%
document = uproot.open("/home/yusuf/Tubitak-1001/output/SimOutput_t0.root")
print(document.keys())
# Out:
# ['DetectorGeo;1', 'GeneralInfo;1', 'NeutronSD;1', 'MainSD;1', 'PhotonSD;1']

# %%
MainSD_Tree = document["NeutronSD"]
print(MainSD_Tree.keys())
# Out:
# ['EventID', 'NeutronAbsNucleusA', 'NeutronCaptureTime', 'NeutronTrackLength', 'NeutronCapturePositionVec']

# %%
another_Tree = MainSD_Tree["NeutronTrackLength"].array(library="np")
patato = another_Tree[:10]
print(patato)
ddd 
print(np.max(another_Tree))
# Out:
# [  0.           0.           0.           0.           0.
#    0.         117.75953756   0.           0.           0.        ]
# 463.1894387712027

# %%
plt.figure(figsize=(10,6))
plt.hist(another_Tree, bins = 90,edgecolor="blue", alpha = 1)

plt.xlabel("x-ekseni")
plt.ylabel("y ekesen")
plt.title("grafuk başluğu")


plt.grid(True)
plt.show()

# %%
import plotly.graph_objects as go

# Grafik Çerçevesini Oluştur
fig = go.Figure()

# Histogramı Ekle
fig.add_trace(go.Histogram(
    x=another_Tree,
    xbins=dict( # Kutucuk ayarları (0 ile 7 arası, 0.07 genişliğinde)
        start=1,
        end=7,
        size=0.07
    ),
    marker_color='orange', # Renk
    opacity=1,
    name='main'
))

# Profesyonel Görünüm Ayarları
fig.update_layout(
    title_text='<b>DEDEKTOR GRAFUĞU</b>', # Kalın Başlık
    xaxis_title_text='Enerju (MeV)',
    yaxis_title_text='Olay Sayısı',
    bargap=0.001, # Çubuklar arası boşluk
    template="plotly_white", # Bilimsel beyaz tema
    hovermode="x unified" # Mouse ile gezince tüm bilgiyi göster
)

# Grafiği Göster
fig.show()
